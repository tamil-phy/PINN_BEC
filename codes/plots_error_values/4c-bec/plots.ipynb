# %%
import numpy as np
from plot_solution import *

# %%
x = np.loadtxt('4c_bec_x.dat')
t = np.loadtxt('4c_bec_t.dat')

q1 = np.loadtxt("4c_bec_q1_pre.dat")
q2 = np.loadtxt("4c_bec_q2_pre.dat")
q3 = np.loadtxt("4c_bec_q3_pre.dat")
q4 = np.loadtxt("4c_bec_q4_pre.dat")

q1_exact = np.loadtxt("4c_bec_q1_ori.dat")
q2_exact = np.loadtxt("4c_bec_q2_ori.dat")
q3_exact = np.loadtxt("4c_bec_q3_ori.dat")
q4_exact = np.loadtxt("4c_bec_q4_ori.dat")

# %%
time_instant = [50, 200, 349]

# %%
fig1 = plot_sol(x, t, q1, q1_exact, time_instant, "plasma", '#FFE033', '#4A048B', '$|q_1(x,t)|^2$')
fig1.savefig('4c_bec_q1.png', dpi=600)

# %%
fig2 = plot_sol(x, t, q2, q2_exact, time_instant, "YlOrRd", '#F6E051', '#CC4700', '$|q_2(x,t)|^2$')
fig2.savefig('4c_bec_q2.png', dpi=600)

# %%
fig3 = plot_sol(x, t, q3, q3_exact, time_instant, "summer", '#94CF26', '#1B5F59', '$|q_3(x,t)|^2$')
fig3.savefig('4c_bec_q3.png', dpi=600)

# %%
fig4 = plot_sol(x, t, q4, q4_exact, time_instant, "RdPu", '#E16684', '#3F0477', '$|q_4(x,t)|^2$')
fig4.savefig('4c_bec_q4.png', dpi=600)

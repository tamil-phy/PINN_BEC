# %%
import numpy as np
from plot_solution import *

# %%
x = np.loadtxt('3c_bec_x.dat')
t = np.loadtxt('3c_bec_t.dat')

q1 = np.loadtxt("3c_bec_q1_pre.dat")
q2 = np.loadtxt("3c_bec_q2_pre.dat")
q3 = np.loadtxt("3c_bec_q3_pre.dat")

q1_exact = np.loadtxt("3c_bec_q1_ori.dat")
q2_exact = np.loadtxt("3c_bec_q2_ori.dat")
q3_exact = np.loadtxt("3c_bec_q3_ori.dat")

# %%
time_instant = [50, 200, 349]

# %%
fig1 = plot_sol(x, t, q1, q1_exact, time_instant, "cool", '#1FEAEA', '#B441AA', '$|q_1(x,t)|^2$')
fig1.savefig('3c_bec_q1_sym.png', dpi=600)

# %%
fig2 = plot_sol(x, t, q2, q2_exact, time_instant, "YlGnBu", '#F0B92D', '#0F7173', '$|q_2(x,t)|^2$')
fig2.savefig('3c_bec_q2_sym.png', dpi=600)

# %%
fig3 = plot_sol(x, t, q3, q3_exact, time_instant, "YlGn", '#94CF26', '#1B5F59', '$|q_3(x,t)|^2$')
fig3.savefig('3c_bec_q3_sym.png', dpi=600)
